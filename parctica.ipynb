# %%
import pandas as pd

# %%
df=pd.read_csv("datasets\\titanic_dataset.csv",sep='\t',header=0)
df
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
df.head()# primeros 5
df.tail()#ultimos 5
df.dtypes# tipo de datos que maneja cada columna
df.shape #dimension de las columnas
# Out:
# (418, 11)

# %%
df.isna().sum() # te muesta los que son nulos y la cantidad de nulos que hay en cada columna
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
import missingno as msn
msn.matrix(df)
# Out:
# <Axes: >

# %%
#eliminar todo lo que este vacio
df.dropna(inplace=True)

# %%
#eliminiar solo las columans que estan vacias
df.dropna(subset=['Age','Fare'],inplace=True)
df['Age'].dropna(inplace=True)

# %%
#llenar con la media, mediana y moda
df['Age'].fillna(df.Age.mode(),inplace=True)
df['Age'].fillna(df.Age.median(),inplace=True)
df['Age'].fillna(df.Age.mean(),inplace=True)
df.Cabin.fillna("?",inplace=True)

# %%
df
# Out:
#      PassengerId  Pclass                                               Name  \
# 12           904       1      Snyder, Mrs. John Pillsbury (Nelle Stevenson)
# 14           906       1  Chaffee, Mrs. Herbert Fuller (Carrie Constance...
# 24           916       1    Ryerson, Mrs. Arthur Larned (Emily Maria Borie)
# 26           918       1                       Ostby, Miss. Helene Ragnhild
# 28           920       1                            Brady, Mr. John Bertram
# ..           ...     ...                                                ...
# 404         1296       1                       Frauenthal, Mr. Isaac Gerald
# 405         1297       2         Nourney, Mr. Alfred (Baron von Drachstedt)
# 407         1299       1                         Widener, Mr. George Dunton
# 411         1303       1    Minahan, Mrs. William Edward (Lillian E Thorpe)
# 414         1306       1                       Oliva y Ocana, Dona. Fermina
#
# ...

# %%
df['Age'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
# te muestra el valor  de la edad y cuantas personas tienen esa edad
df.Age.value_counts()
# Out:
# Age
# 55.0    4
# 48.0    4
# 36.0    4
# 30.0    4
# 45.0    4
# 27.0    3
# 39.0    3
# 25.0    3
# 23.0    3
# 64.0    3
# 50.0    3
# 42.0    2
# 54.0    2
# 37.0    2
# 53.0    2
# 47.0    2
# 26.0    2
# 43.0    2
# 18.0    2
# 35.0    2
# 31.0    2
# 24.0    2
# 60.0    2
# 41.0    2
# 22.0    2
# 12.0    1
# 57.0    1
# 33.0    1
# 59.0    1
# 46.0    1
# 49.0    1
# 51.0    1
# 58.0    1
# 63.0    1
# 6.0     1
# 29.0    1
# 61.0    1
# 1.0     1
# 18.5    1
# 76.0    1
# 67.0    1
# 32.5    1
# 28.5    1
# 13.0    1
# 28.0    1
# 20.0    1
# Name: count, dtype: int64

# %%
#para mostrar solo las columnas que quieres ver la primera es la notacion corchetes y la segunda es la notacion punto

df[['Age',"Sex"]]# para mas de una usamos un arreglo para mostrarlos 
# solo para mostrar una
df.Age
# Out:
# 12     23.0
# 14     47.0
# 24     48.0
# 26     22.0
# 28     41.0
#        ...
# 404    43.0
# 405    20.0
# 407    50.0
# 411    37.0
# 414    39.0
# Name: Age, Length: 87, dtype: float64

# %%
#solo te mostrara los valores que inicien con los valores indicados en la sentancia
df[(df.Name.str.startswith("Ke"))|(df.Name.str.startswith("Pe"))]
df[(df.Name.str.startswith("Ke"))]
# Out:
#      PassengerId  Pclass                     Name   Sex   Age  SibSp  Parch  \
# 75           967       1       Keeping, Mr. Edwin  male  32.5      0      0
# 245         1137       1  Kenyon, Mr. Frederick R  male  41.0      1      0
#
#      Ticket      Fare Cabin Embarked
# 75   113503  211.5000  C132        C
# 245   17464   51.8625   D21        S

# %%
#para crear una nueva columna 
df['cositas'] = (df['Age'] * df['Pclass'])
df
# Out:
#      PassengerId  Pclass                                               Name  \
# 12           904       1      Snyder, Mrs. John Pillsbury (Nelle Stevenson)
# 14           906       1  Chaffee, Mrs. Herbert Fuller (Carrie Constance...
# 24           916       1    Ryerson, Mrs. Arthur Larned (Emily Maria Borie)
# 26           918       1                       Ostby, Miss. Helene Ragnhild
# 28           920       1                            Brady, Mr. John Bertram
# ..           ...     ...                                                ...
# 404         1296       1                       Frauenthal, Mr. Isaac Gerald
# 405         1297       2         Nourney, Mr. Alfred (Baron von Drachstedt)
# 407         1299       1                         Widener, Mr. George Dunton
# 411         1303       1    Minahan, Mrs. William Edward (Lillian E Thorpe)
# 414         1306       1                       Oliva y Ocana, Dona. Fermina
#
# ...

# %%
#para mostrar cierto dato en la columna y los primeros 6
df_17=df[df.Age<=17]
df_17.head(6)
# Out:
#      PassengerId  Pclass                             Name     Sex   Age  \
# 64           956       1      Ryerson, Master. John Borie    male  13.0
# 117         1009       3  Sandstrom, Miss. Beatrice Irene  female   1.0
# 196         1088       1  Spedden, Master. Robert Douglas    male   6.0
# 326         1218       2     Becker, Miss. Ruth Elizabeth  female  12.0
#
#      SibSp  Parch    Ticket     Fare            Cabin Embarked  cositas
# 64       2      2  PC 17608  262.375  B57 B59 B63 B66        C     13.0
# 117      1      1   PP 9549   16.700               G6        S      3.0
# 196      0      2     16966  134.500              E34        C      6.0
# 326      2      1    230136   39.000               F4        S     24.0

# %%
# te ordena por Fare y te muestra los primeros 6
df_17.sort_values(by="Fare",ascending=False).head(6)
# Out:
#      PassengerId  Pclass                             Name     Sex   Age  \
# 64           956       1      Ryerson, Master. John Borie    male  13.0
# 196         1088       1  Spedden, Master. Robert Douglas    male   6.0
# 326         1218       2     Becker, Miss. Ruth Elizabeth  female  12.0
# 117         1009       3  Sandstrom, Miss. Beatrice Irene  female   1.0
#
#      SibSp  Parch    Ticket     Fare            Cabin Embarked  cositas
# 64       2      2  PC 17608  262.375  B57 B59 B63 B66        C     13.0
# 196      0      2     16966  134.500              E34        C      6.0
# 326      2      1    230136   39.000               F4        S     24.0
# 117      1      1   PP 9549   16.700               G6        S      3.0

# %% [markdown]
# unidad 2

# %%
df=pd.read_csv("datasets/auto_mpg_data_tvs.txt",sep='\t',header=0)
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0      130.0  3504.0          12.0
# 1    15.0          8         350.0      165.0  3693.0          11.5
# 2    18.0          8         318.0      150.0  3436.0          11.0
# 3    16.0          8         304.0      150.0  3433.0          12.0
# 4    17.0          8         302.0      140.0  3449.0          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0      86.00  2790.0          15.6
# 394  44.0          4          97.0      52.00  2130.0          24.6
# 395  32.0          4         135.0      84.00  2295.0          11.6
# 396  28.0          4         120.0      79.00  2625.0          18.6
# 397  31.0          4         119.0      82.00  2720.0          19.4
#
#      model_year  origin                   car_name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
#tendencia central
#media =23.514572864321607
df.mpg.mean()
#mediana=23
df.mpg.median()
#moda=13
df.mpg.mode()
# Out:
# 0    13.0
# Name: mpg, dtype: float64

# %%
#dispersion=9
min= df.mpg.min()
max=df.mpg.max()

rango=max-min
rango
# Out:
# 37.6

# %%
#varianza =61.089610774274405
df.mpg.var()
# Out:
# 61.089610774274405

# %%
#desviacion estandar=7.815984312565782
df.mpg.std()
# Out:
# 7.815984312565782

# %%
df.mpg.quantile([.25,.50,.75]) #si ahcemos la cuenta y no coinciden la cuenta la mediana y el cuartil es lo mismo
df.mpg.quantile([.20,.40,.60,.80])
# Out:
# 0.2    16.0
# 0.4    20.0
# 0.6    25.0
# 0.8    31.0
# Name: mpg, dtype: float64

# %%
#sesgo
df.mpg.skew()
# Out:
# 0.45706634399491913

# %%
#
df.mpg.kurtosis()
# Out:
# -0.5107812652123154

# %%
df.mpg.count()
# Out:
# 398

# %%
#cual es promedio dde cylinders de los autos agrupados por ano 

#forma 1
#df.groupby('model_year')['cylinders'].mean()
df.groupby(df.model_year)['cylinders'].mean()
# Out:
# model_year
# 70    6.758621
# 71    5.571429
# 72    5.821429
# 73    6.375000
# 74    5.259259
# 75    5.600000
# 76    5.647059
# 77    5.464286
# 78    5.361111
# 79    5.827586
# 80    4.137931
# 81    4.620690
# 82    4.193548
# Name: cylinders, dtype: float64

# %%
#cual es el promedio de cylindros  de los autos agrupados por ano y por origen 
df.groupby(['model_year','origin'])['cylinders'].mean()
# Out:
# model_year  origin
# 70          1         7.636364
#             2         4.000000
#             3         4.000000
# 71          1         6.200000
#             2         4.000000
#             3         4.000000
# 72          1         6.888889
#             2         4.000000
#             3         3.800000
# 73          1         7.241379
#             2         4.000000
#             3         4.250000
# 74          1         6.266667
#             2         4.000000
#             3         4.000000
# 75          1         6.400000
#             2         4.000000
#             3         4.000000
# 76          1         6.363636
#             2         4.250000
#             3         4.500000
# 77          1         6.222222
#             2         4.000000
#             3         4.166667
# 78          1         6.000000
#             2         4.833333
#             3         4.000000
# 79          1         6.260870
#             2         4.250000
# ...

# %%
df.groupby(['model_year','origin'])['cylinders'].agg(['mean','median'])
# Out:
#                        mean  median
# model_year origin
# 70         1       7.636364     8.0
#            2       4.000000     4.0
#            3       4.000000     4.0
# 71         1       6.200000     6.0
#            2       4.000000     4.0
#            3       4.000000     4.0
# 72         1       6.888889     8.0
#            2       4.000000     4.0
#            3       3.800000     4.0
# 73         1       7.241379     8.0
#            2       4.000000     4.0
#            3       4.250000     4.0
# 74         1       6.266667     6.0
#            2       4.000000     4.0
#            3       4.000000     4.0
# 75         1       6.400000     6.0
#            2       4.000000     4.0
#            3       4.000000     4.0
# 76         1       6.363636     6.0
#            2       4.250000     4.0
#            3       4.500000     4.0
# 77         1       6.222222     6.0
#            2       4.000000     4.0
#            3       4.166667     4.0
# ...

# %%
df.groupby(['model_year','origin']).agg({'cylinders':'mean','mpg':'median'})
# Out:
#                    cylinders    mpg
# model_year origin
# 70         1        7.636364  15.00
#            2        4.000000  25.00
#            3        4.000000  25.50
# 71         1        6.200000  18.00
#            2        4.000000  29.00
#            3        4.000000  29.00
# 72         1        6.888889  14.00
#            2        4.000000  22.00
#            3        3.800000  24.00
# 73         1        7.241379  14.00
#            2        4.000000  24.00
#            3        4.250000  20.00
# 74         1        6.266667  16.00
#            2        4.000000  26.00
#            3        4.000000  31.00
# 75         1        6.400000  17.50
#            2        4.000000  24.00
#            3        4.000000  26.50
# 76         1        6.363636  18.25
#            2        4.250000  26.00
#            3        4.500000  30.00
# 77         1        6.222222  18.00
#            2        4.000000  29.75
#            3        4.166667  28.00
# ...

# %%
df.groupby(['model_year','origin']).agg({'cylinders':['mean','median'],'mpg':'median'})
# Out:
#                   cylinders           mpg
#                        mean median median
# model_year origin
# 70         1       7.636364    8.0  15.00
#            2       4.000000    4.0  25.00
#            3       4.000000    4.0  25.50
# 71         1       6.200000    6.0  18.00
#            2       4.000000    4.0  29.00
#            3       4.000000    4.0  29.00
# 72         1       6.888889    8.0  14.00
#            2       4.000000    4.0  22.00
#            3       3.800000    4.0  24.00
# 73         1       7.241379    8.0  14.00
#            2       4.000000    4.0  24.00
#            3       4.250000    4.0  20.00
# 74         1       6.266667    6.0  16.00
#            2       4.000000    4.0  26.00
#            3       4.000000    4.0  31.00
# 75         1       6.400000    6.0  17.50
#            2       4.000000    4.0  24.00
#            3       4.000000    4.0  26.50
# 76         1       6.363636    6.0  18.25
#            2       4.250000    4.0  26.00
# ...
